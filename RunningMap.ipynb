# %% [markdown]
# <a href="https://colab.research.google.com/github/tinyAtlas/RunningBR/blob/main/RunningMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Running Graph V0

# %% [markdown]
# Import running data uploaded to Drive

# %%
from google.colab import drive
# it will link to your google drive and may ask you to go through a verification step
drive.mount('/content/drive') 

# Path to folders with training data
run_path = '/content/drive/MyDrive/Projects/Running/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gpx-converter

from gpx_converter import Converter

# %%
#Lets look at one?

import glob
gpx_files = glob.glob(run_path + '*.gpx')

# %%
import pandas as pd

print(type(Converter(input_file=gpx_files[0]).gpx_to_dataframe()))
frames = []

for gpx_file in glob.glob(run_path + '*.gpx'):
  #print(temp)
  frames.append(Converter(input_file=gpx_file).gpx_to_dataframe())
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#result = frames[-12:]
result = frames
result = pd.concat(result)
result['year'] = result['time'].dt.year
result = (result[result.year > 2020])
print(result)
# Out:
#                           time   latitude  longitude  altitude  year
# 0    2021-01-14 12:59:22+00:00  51.463279  -2.603733      77.1  2021
# 1    2021-01-14 12:59:23+00:00  51.463361  -2.603763      77.0  2021
# 2    2021-01-14 12:59:25+00:00  51.463367  -2.603730      77.0  2021
# 3    2021-01-14 12:59:27+00:00  51.463389  -2.603688      77.0  2021
# 4    2021-01-14 12:59:28+00:00  51.463394  -2.603668      77.0  2021
# ...                        ...        ...        ...       ...   ...
# 1060 2021-01-27 17:51:08+00:00  51.464056  -2.604873      61.5  2021
# 1061 2021-01-27 17:51:10+00:00  51.464075  -2.604892      61.5  2021
# 1062 2021-01-27 17:51:11+00:00  51.464082  -2.604898      61.5  2021
# 1063 2021-01-27 17:51:12+00:00  51.464068  -2.604882      61.5  2021
# 1064 2021-01-27 17:51:14+00:00  51.464050  -2.604865      61.6  2021
#
# [9661 rows x 5 columns]

# %%
#print(result)
import matplotlib.pyplot as plt

fig= plt.figure(figsize=(10,10))
plt.scatter(x=result['longitude'], y=result['latitude'],s=0.3)

#plt.figure()
plt.show()
